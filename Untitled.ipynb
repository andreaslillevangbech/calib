# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import torchvision

# %%
GT_DIR = 'labeled/'
flow = 'flows0/'
vid = '0/'
imgs = os.listdir(GT_DIR+vid)
flows = os.listdir(GT_DIR+flow)

# %%
img = cv2.imread(GT_DIR + vid + imgs[0])
width, height, chan = img.shape
margin = int(width // 2.5)
top = 70
bot = 80
im1 = img[top:-bot, margin:-margin, :]
plt.imshow(im1)

# %%
# Out:
# (50, 80)

# %%
from torchvision.transforms.functional import crop
flo = Image.open(GT_DIR + vid + imgs[0])
width, height = flo.size
print(width)
top = 80
left = 102
print(left)
w = width - 2*left
flo = crop(flo, 85, left, 35, w)

# plt.imshow(flo)
flo.size
# Out:
# 224
# 102
# (20, 35)
